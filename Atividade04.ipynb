# %% [markdown]
# <a href="https://colab.research.google.com/github/MikiAndrade/MODULO-I/blob/main/Atividade04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CENTRO DE EDUCAÇÃO DE TECNOLOGIA DO AMAZONAS - IBC MANAUS 24 DE MARÇO DE 2026
#
# Aluna: Mikiline Andrade

# %%
print("Curso Técnico em Nível Médio de Inteligência Artificial - Turma 2026.1")
# Out:
# Curso Técnico em Nível Médio de Inteligência Artificial - Turma 2026.1

# %%
nu1, nu2 = 0, 0
print('ola, mundo!')

print(5 + 5 - 2)
print(nu1)

print (5 ** 2)
print(nu2)
# Out:
# ola, mundo!
# 8
# 0
# 25
# 0

# %%
# Script 1
# Função criada pelo usuário
def dobro(x):
    print(x * 2)

dobro(125)
# Out:
# 250

# %%
x = 1
if x == 1:
    # recuo de 4 espaços em branco
    print("x é 1.")
y = 33
# Out:
# x é 1.

# %%
print("Oi pessoal!")
# Out:
# Oi pessoal!
